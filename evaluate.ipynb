# %% [markdown]
# 구현해야 할 것
# - HeatmapParser
# - flipped ensemble evaluation
# - Dataset analysis
# - (v) mpii_eval
# - (v) generator for mpii_eval(img, gts)

# %%
from data.dp import Dataset

import os
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from task.eval import HumanPoseEstimator
from task.eval import show_hms
# Out:
# INFO:tensorflow:Enabling eager execution
# INFO:tensorflow:Enabling v2 tensorshape
# INFO:tensorflow:Enabling resource variables
# INFO:tensorflow:Enabling tensor equality
# INFO:tensorflow:Enabling control flow v2

# %%
INPUT_RES = 256
OUTPUT_RES = 64
NUM_PARTS = 16
EPOCH = 5

HPE = HumanPoseEstimator(INPUT_RES, OUTPUT_RES, NUM_PARTS, EPOCH)
# Out:
# Model: "HPE"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 128, 128, 64) 9472        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 128, 128, 64) 256         conv2d[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu (TFOpLambda)         (None, 128, 128, 64) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv_block (ConvBlock)          (None, 128, 128, 128 73600       tf.nn.relu[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 64, 64, 128)  0           conv_block[0][0]
# __________________________________________________________________________________________________
# conv_block_1 (ConvBlock)        (None, 64, 64, 128)  102272      average_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv_block_2 (ConvBlock)        (None, 64, 64, 256)  292608      conv_block_1[0][0]
# __________________________________________________________________________________________________
# hour_glass (HourGlass)          (None, 64, 64, 256)  5428992     conv_block_2[0][0]
# __________________________________________________________________________________________________
# conv_block_16 (ConvBlock)       (None, 64, 64, 256)  407296      hour_glass[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 64, 64, 256)  65792       conv_block_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 64, 64, 256)  1024        conv2d_58[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_1 (TFOpLambda)       (None, 64, 64, 256)  0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 64, 64, 256)  65792       tf.nn.relu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 64, 64, 16)   4112        tf.nn.relu_1[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add (TFOpLambd (None, 64, 64, 256)  0           conv_block_2[0][0]
#                                                                  conv2d_60[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 64, 64, 256)  4352        conv2d_59[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_1 (TFOpLam (None, 64, 64, 256)  0           tf.__operators__.add[0][0]
#                                                                  conv2d_61[0][0]
# __________________________________________________________________________________________________
# hour_glass_1 (HourGlass)        (None, 64, 64, 256)  5428992     tf.__operators__.add_1[0][0]
# __________________________________________________________________________________________________
# conv_block_30 (ConvBlock)       (None, 64, 64, 256)  407296      hour_glass_1[0][0]
# __________________________________________________________________________________________________
# conv2d_108 (Conv2D)             (None, 64, 64, 256)  65792       conv_block_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_113 (BatchN (None, 64, 64, 256)  1024        conv2d_108[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_2 (TFOpLambda)       (None, 64, 64, 256)  0           batch_normalization_113[0][0]
# __________________________________________________________________________________________________
# conv2d_110 (Conv2D)             (None, 64, 64, 256)  65792       tf.nn.relu_2[0][0]
# __________________________________________________________________________________________________
# conv2d_109 (Conv2D)             (None, 64, 64, 16)   4112        tf.nn.relu_2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_2 (TFOpLam (None, 64, 64, 256)  0           tf.__operators__.add_1[0][0]
#                                                                  conv2d_110[0][0]
# __________________________________________________________________________________________________
# conv2d_111 (Conv2D)             (None, 64, 64, 256)  4352        conv2d_109[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_3 (TFOpLam (None, 64, 64, 256)  0           tf.__operators__.add_2[0][0]
#                                                                  conv2d_111[0][0]
# __________________________________________________________________________________________________
# hour_glass_2 (HourGlass)        (None, 64, 64, 256)  5428992     tf.__operators__.add_3[0][0]
# __________________________________________________________________________________________________
# conv_block_44 (ConvBlock)       (None, 64, 64, 256)  407296      hour_glass_2[0][0]
# __________________________________________________________________________________________________
# conv2d_158 (Conv2D)             (None, 64, 64, 256)  65792       conv_block_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_164 (BatchN (None, 64, 64, 256)  1024        conv2d_158[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_3 (TFOpLambda)       (None, 64, 64, 256)  0           batch_normalization_164[0][0]
# __________________________________________________________________________________________________
# conv2d_160 (Conv2D)             (None, 64, 64, 256)  65792       tf.nn.relu_3[0][0]
# __________________________________________________________________________________________________
# conv2d_159 (Conv2D)             (None, 64, 64, 16)   4112        tf.nn.relu_3[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_4 (TFOpLam (None, 64, 64, 256)  0           tf.__operators__.add_3[0][0]
#                                                                  conv2d_160[0][0]
# __________________________________________________________________________________________________
# conv2d_161 (Conv2D)             (None, 64, 64, 256)  4352        conv2d_159[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_5 (TFOpLam (None, 64, 64, 256)  0           tf.__operators__.add_4[0][0]
#                                                                  conv2d_161[0][0]
# __________________________________________________________________________________________________
# hour_glass_3 (HourGlass)        (None, 64, 64, 256)  5428992     tf.__operators__.add_5[0][0]
# __________________________________________________________________________________________________
# conv_block_58 (ConvBlock)       (None, 64, 64, 256)  407296      hour_glass_3[0][0]
# __________________________________________________________________________________________________
# conv2d_208 (Conv2D)             (None, 64, 64, 256)  65792       conv_block_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_215 (BatchN (None, 64, 64, 256)  1024        conv2d_208[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_4 (TFOpLambda)       (None, 64, 64, 256)  0           batch_normalization_215[0][0]
# __________________________________________________________________________________________________
# conv2d_209 (Conv2D)             (None, 64, 64, 16)   4112        tf.nn.relu_4[0][0]
# ==================================================================================================
# Total params: 24,317,504
# Trainable params: 24,257,216
# Non-trainable params: 60,288
# __________________________________________________________________________________________________

# %%
test_dir = 'data/test'
test_list = os.listdir(test_dir)
test_list.remove('result')
for test in test_list:
    src = os.path.join(test_dir, test)
    dst = os.path.join(test_dir, 'result', test)
    img, hms, joints = HPE.inference(src, dst)
# Out:
# Saved "data/test/result/test002.jpg"
# Saved "data/test/result/test004.jpg"
# Saved "data/test/result/test003.jpg"
# Saved "data/test/result/test005.png"
# Saved "data/test/result/test001.png"

# %%
show_hms(hms)

# %%
HPE.eval_PCK()
# Out:
# loading data: valid.h5
# Done (t=0.44s)
#   1%|▏         | 41/2958 [00:02<03:08, 15.47it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-14afc7dc3491> in <module>
# ----> 1 HPE.eval_PCK()
#
# ~/code/Human-Pose-Estimation/eval.py in eval_PCK(self)
#     131         total_gts = []
#     132         total_n = []
# --> 133         for data in tqdm(generator, total=len(self.dataset.idx_list), file=sys.stdout):
#     134             img, gts, n = (data[0], data[1][0], data[2])
#     135             hms = self.model.predict(img)[0]
#
# ~/.local/lib/python3.8/site-packages/tqdm/std.py in __iter__(self)
#    1176
#    1177         try:
# -> 1178             for obj in iterable:
#    1179                 yield obj
#    1180                 # Update and possibly print the progressbar.
#
# ~/code/Human-Pose-Estimation/data/dp.py in gen_eval(self)
#      80     def gen_eval(self):
#      81         for idx in self.idx_list:
# ---> 82             img, keypoints, normalizing = self.loadImage(idx, True)
#      83             yield img, keypoints, normalizing
#      84
#
# ~/code/Human-Pose-Estimation/data/dp.py in loadImage(self, idx, eval)
#      87
#      88         ## load + crop
# ---> 89         orig_img = ds.get_img(idx)
#      90         path = ds.get_path(idx)
#      91         orig_keypoints = ds.get_kps(idx)
#
# ~/code/Human-Pose-Estimation/data/ref.py in get_img(self, idx)
#      47         path = os.path.join(img_dir, imgname)
#      48         img = tf.io.read_file(path)
# ---> 49         img = tf.image.decode_jpeg(img, channels=3)
#      50         return img
#      51
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/ops/gen_image_ops.py in decode_jpeg(contents, channels, ratio, fancy_upscaling, try_recover_truncated, acceptable_fraction, dct_method, name)
#    1168       pass
#    1169     try:
# -> 1170       return decode_jpeg_eager_fallback(
#    1171           contents, channels=channels, ratio=ratio,
#    1172           fancy_upscaling=fancy_upscaling,
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/ops/gen_image_ops.py in decode_jpeg_eager_fallback(contents, channels, ratio, fancy_upscaling, try_recover_truncated, acceptable_fraction, dct_method, name, ctx)
#    1242   fancy_upscaling, "try_recover_truncated", try_recover_truncated,
#    1243   "acceptable_fraction", acceptable_fraction, "dct_method", dct_method)
# -> 1244   _result = _execute.execute(b"DecodeJpeg", 1, inputs=_inputs_flat,
#    1245                              attrs=_attrs, ctx=ctx, name=name)
#    1246   if _execute.must_record_gradient():
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
print(len(joints))
# Out:
# 64

# %%
jointmap = np.zeros((64*64), dtype=np.float32)
joint = []
for i in range(hms.shape[2]):
    idx = np.argmax(hms[:,:,i])
    jointmap[idx] = 1
    joint.append((idx % 64, idx // 64))
jointmap = jointmap.reshape((64, 64))
plt.imshow(jointmap)

# %%
joints = np.array(joints)/64*256

# %%
pairs = [[0, 1], [1, 2], [2, 6], [6, 3], [3, 4], [4, 5], [6, 7], [7, 8], [8, 9], [10, 11], [11, 12], [12, 7], [15, 14], [14, 13], [13, 7]]

# %%
bone = []
for pair in pairs:
    b = []
    for p in pair:
        b.append(joints[p])
    bone.append(b)

# %%
bone = np.array(bone)
plt.imshow(img[0])

for b in bone:
    x = []
    y = []
    for _x, _y in b:
        x.append(_x)
        y.append(_y)
    plt.plot(x, y)
