# %%
from tasks.model import FacialLandmarkDetector, lr_scheduler
from libs.dp import Dataset
import tensorflow as tf
import matplotlib.pyplot as plt
import os
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
model = FacialLandmarkDetector()
# Out:
# Model: "HPE"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(16, 256, 256, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (16, 128, 128, 64)   9472        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (16, 128, 128, 64)   256         conv2d[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu (TFOpLambda)         (16, 128, 128, 64)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv_block (ConvBlock)          (16, 128, 128, 128)  73600       tf.nn.relu[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (16, 64, 64, 128)    0           conv_block[0][0]
# __________________________________________________________________________________________________
# conv_block_1 (ConvBlock)        (16, 64, 64, 128)    102272      average_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv_block_2 (ConvBlock)        (16, 64, 64, 256)    292608      conv_block_1[0][0]
# __________________________________________________________________________________________________
# hour_glass (HourGlass)          (16, 64, 64, 256)    5294848     conv_block_2[0][0]
# __________________________________________________________________________________________________
# conv_block_16 (ConvBlock)       (16, 64, 64, 256)    407296      hour_glass[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (16, 64, 64, 256)    65792       conv_block_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (16, 64, 64, 256)    1024        conv2d_54[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_1 (TFOpLambda)       (16, 64, 64, 256)    0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (16, 64, 64, 256)    65792       tf.nn.relu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (16, 64, 64, 68)     17476       tf.nn.relu_1[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add (TFOpLambd (16, 64, 64, 256)    0           conv_block_2[0][0]
#                                                                  conv2d_56[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (16, 64, 64, 256)    17664       conv2d_55[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_1 (TFOpLam (16, 64, 64, 256)    0           tf.__operators__.add[0][0]
#                                                                  conv2d_57[0][0]
# __________________________________________________________________________________________________
# hour_glass_1 (HourGlass)        (16, 64, 64, 256)    5294848     tf.__operators__.add_1[0][0]
# __________________________________________________________________________________________________
# conv_block_30 (ConvBlock)       (16, 64, 64, 256)    407296      hour_glass_1[0][0]
# __________________________________________________________________________________________________
# conv2d_100 (Conv2D)             (16, 64, 64, 256)    65792       conv_block_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_97 (BatchNo (16, 64, 64, 256)    1024        conv2d_100[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_2 (TFOpLambda)       (16, 64, 64, 256)    0           batch_normalization_97[0][0]
# __________________________________________________________________________________________________
# conv2d_102 (Conv2D)             (16, 64, 64, 256)    65792       tf.nn.relu_2[0][0]
# __________________________________________________________________________________________________
# conv2d_101 (Conv2D)             (16, 64, 64, 68)     17476       tf.nn.relu_2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_2 (TFOpLam (16, 64, 64, 256)    0           tf.__operators__.add_1[0][0]
#                                                                  conv2d_102[0][0]
# __________________________________________________________________________________________________
# conv2d_103 (Conv2D)             (16, 64, 64, 256)    17664       conv2d_101[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_3 (TFOpLam (16, 64, 64, 256)    0           tf.__operators__.add_2[0][0]
#                                                                  conv2d_103[0][0]
# __________________________________________________________________________________________________
# hour_glass_2 (HourGlass)        (16, 64, 64, 256)    5294848     tf.__operators__.add_3[0][0]
# __________________________________________________________________________________________________
# conv_block_44 (ConvBlock)       (16, 64, 64, 256)    407296      hour_glass_2[0][0]
# __________________________________________________________________________________________________
# conv2d_146 (Conv2D)             (16, 64, 64, 256)    65792       conv_block_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_140 (BatchN (16, 64, 64, 256)    1024        conv2d_146[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_3 (TFOpLambda)       (16, 64, 64, 256)    0           batch_normalization_140[0][0]
# __________________________________________________________________________________________________
# conv2d_148 (Conv2D)             (16, 64, 64, 256)    65792       tf.nn.relu_3[0][0]
# __________________________________________________________________________________________________
# conv2d_147 (Conv2D)             (16, 64, 64, 68)     17476       tf.nn.relu_3[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_4 (TFOpLam (16, 64, 64, 256)    0           tf.__operators__.add_3[0][0]
#                                                                  conv2d_148[0][0]
# __________________________________________________________________________________________________
# conv2d_149 (Conv2D)             (16, 64, 64, 256)    17664       conv2d_147[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_5 (TFOpLam (16, 64, 64, 256)    0           tf.__operators__.add_4[0][0]
#                                                                  conv2d_149[0][0]
# __________________________________________________________________________________________________
# hour_glass_3 (HourGlass)        (16, 64, 64, 256)    5294848     tf.__operators__.add_5[0][0]
# __________________________________________________________________________________________________
# conv_block_58 (ConvBlock)       (16, 64, 64, 256)    407296      hour_glass_3[0][0]
# __________________________________________________________________________________________________
# conv2d_192 (Conv2D)             (16, 64, 64, 256)    65792       conv_block_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_183 (BatchN (16, 64, 64, 256)    1024        conv2d_192[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_4 (TFOpLambda)       (16, 64, 64, 256)    0           batch_normalization_183[0][0]
# __________________________________________________________________________________________________
# conv2d_193 (Conv2D)             (16, 64, 64, 68)     17476       tf.nn.relu_4[0][0]
# ==================================================================================================
# Total params: 23,874,320
# Trainable params: 23,820,176
# Non-trainable params: 54,144
# __________________________________________________________________________________________________

# %%
# checkpoint

checkpoint_path = "data/checkpoint_model/cp-{epoch:04d}.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

cp_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path, 
    verbose=1, 
    save_weights_only=True,
    save_freq='epoch')

model.save_weights(checkpoint_path.format(epoch=0))

# %%
IMG_RES = 256
HMS_RES = 64
NUM_LANDMARKS = 68
BATCH_SIZE = 16
DATASET_DIR = '../Data/300W_train/train.csv'

dataset = Dataset(IMG_RES, HMS_RES, NUM_LANDMARKS, DATASET_DIR)
dataset_generator = dataset.tf_dataset_from_generator(BATCH_SIZE)
# Out:
# Train dataset is loaded. Shape: (3837, 2)

# %%
lr = tf.keras.callbacks.LearningRateScheduler(lr_scheduler)

# %%
hist = model.fit(dataset_generator.take(240), callbacks=[lr, cp_callback], epochs=100)
# Out:
# Epoch 1/100
# 240/240 [==============================] - 315s 1s/step - loss: 0.0110
#
# Epoch 00001: saving model to data/checkpoint_model/cp-0001.ckpt
# Epoch 2/100
# 240/240 [==============================] - 303s 1s/step - loss: 0.0023
#
# Epoch 00002: saving model to data/checkpoint_model/cp-0002.ckpt
# Epoch 3/100
# 240/240 [==============================] - 301s 1s/step - loss: 0.0022
#
# Epoch 00003: saving model to data/checkpoint_model/cp-0003.ckpt
# Epoch 4/100
# 240/240 [==============================] - 300s 1s/step - loss: 0.0020
#
# Epoch 00004: saving model to data/checkpoint_model/cp-0004.ckpt
# Epoch 5/100
# 240/240 [==============================] - 301s 1s/step - loss: 0.0017
#
# Epoch 00005: saving model to data/checkpoint_model/cp-0005.ckpt
# Epoch 6/100
# 240/240 [==============================] - 302s 1s/step - loss: 0.0015
#
# Epoch 00006: saving model to data/checkpoint_model/cp-0006.ckpt
# Epoch 7/100
# 240/240 [==============================] - 299s 1s/step - loss: 0.0013
#
# Epoch 00007: saving model to data/checkpoint_model/cp-0007.ckpt
# Epoch 8/100
# 240/240 [==============================] - 298s 1s/step - loss: 0.0012
#
# Epoch 00008: saving model to data/checkpoint_model/cp-0008.ckpt
# Epoch 9/100
# 240/240 [==============================] - 301s 1s/step - loss: 0.0011
#
# Epoch 00009: saving model to data/checkpoint_model/cp-0009.ckpt
# Epoch 10/100
# 240/240 [==============================] - 301s 1s/step - loss: 0.0010
#
# Epoch 00010: saving model to data/checkpoint_model/cp-0010.ckpt
# Epoch 11/100
# 240/240 [==============================] - 302s 1s/step - loss: 9.3033e-04
#
# Epoch 00011: saving model to data/checkpoint_model/cp-0011.ckpt
# Epoch 12/100
# 240/240 [==============================] - 300s 1s/step - loss: 8.4479e-04
#
# Epoch 00012: saving model to data/checkpoint_model/cp-0012.ckpt
# Epoch 13/100
# 240/240 [==============================] - 299s 1s/step - loss: 7.8876e-04
#
# Epoch 00013: saving model to data/checkpoint_model/cp-0013.ckpt
# Epoch 14/100
# 240/240 [==============================] - 299s 1s/step - loss: 7.3305e-04
#
# Epoch 00014: saving model to data/checkpoint_model/cp-0014.ckpt
# Epoch 15/100
# 240/240 [==============================] - 300s 1s/step - loss: 6.8314e-04
#
# Epoch 00015: saving model to data/checkpoint_model/cp-0015.ckpt
# Epoch 16/100
# 240/240 [==============================] - 301s 1s/step - loss: 6.3888e-04
#
# Epoch 00016: saving model to data/checkpoint_model/cp-0016.ckpt
# Epoch 17/100
# 240/240 [==============================] - 300s 1s/step - loss: 6.0549e-04
#
# Epoch 00017: saving model to data/checkpoint_model/cp-0017.ckpt
# Epoch 18/100
# 240/240 [==============================] - 299s 1s/step - loss: 5.7697e-04
#
# Epoch 00018: saving model to data/checkpoint_model/cp-0018.ckpt
# Epoch 19/100
# 240/240 [==============================] - 299s 1s/step - loss: 5.5282e-04
#
# Epoch 00019: saving model to data/checkpoint_model/cp-0019.ckpt
# Epoch 20/100
# 240/240 [==============================] - 300s 1s/step - loss: 5.2733e-04
#
# Epoch 00020: saving model to data/checkpoint_model/cp-0020.ckpt
# Epoch 21/100
# 240/240 [==============================] - 300s 1s/step - loss: 4.6154e-04
#
# Epoch 00021: saving model to data/checkpoint_model/cp-0021.ckpt
# Epoch 22/100
# 240/240 [==============================] - 301s 1s/step - loss: 4.4617e-04
#
# Epoch 00022: saving model to data/checkpoint_model/cp-0022.ckpt
# Epoch 23/100
# 240/240 [==============================] - 301s 1s/step - loss: 4.3963e-04
#
# Epoch 00023: saving model to data/checkpoint_model/cp-0023.ckpt
# Epoch 24/100
# 240/240 [==============================] - 300s 1s/step - loss: 4.3343e-04
#
# Epoch 00024: saving model to data/checkpoint_model/cp-0024.ckpt
# Epoch 25/100
# 240/240 [==============================] - 299s 1s/step - loss: 4.2782e-04
#
# Epoch 00025: saving model to data/checkpoint_model/cp-0025.ckpt
# Epoch 26/100
# 240/240 [==============================] - 299s 1s/step - loss: 4.2345e-04
#
# Epoch 00026: saving model to data/checkpoint_model/cp-0026.ckpt
# Epoch 27/100
# 240/240 [==============================] - 299s 1s/step - loss: 4.1844e-04
#
# Epoch 00027: saving model to data/checkpoint_model/cp-0027.ckpt
# Epoch 28/100
# 240/240 [==============================] - 300s 1s/step - loss: 4.2040e-04
#
# Epoch 00028: saving model to data/checkpoint_model/cp-0028.ckpt
# Epoch 29/100
# 240/240 [==============================] - 300s 1s/step - loss: 4.0838e-04
#
# Epoch 00029: saving model to data/checkpoint_model/cp-0029.ckpt
# Epoch 30/100
# 240/240 [==============================] - 298s 1s/step - loss: 4.0234e-04
#
# Epoch 00030: saving model to data/checkpoint_model/cp-0030.ckpt
# Epoch 31/100
# 240/240 [==============================] - 297s 1s/step - loss: 3.8355e-04
#
# Epoch 00031: saving model to data/checkpoint_model/cp-0031.ckpt
# Epoch 32/100
# 240/240 [==============================] - 298s 1s/step - loss: 3.7901e-04
#
# Epoch 00032: saving model to data/checkpoint_model/cp-0032.ckpt
# Epoch 33/100
# 240/240 [==============================] - 300s 1s/step - loss: 3.7638e-04
#
# Epoch 00033: saving model to data/checkpoint_model/cp-0033.ckpt
# Epoch 34/100
# 240/240 [==============================] - 301s 1s/step - loss: 3.7482e-04
#
# Epoch 00034: saving model to data/checkpoint_model/cp-0034.ckpt
# Epoch 35/100
# 240/240 [==============================] - 301s 1s/step - loss: 3.7327e-04
#
# Epoch 00035: saving model to data/checkpoint_model/cp-0035.ckpt
# Epoch 36/100
# 240/240 [==============================] - 300s 1s/step - loss: 3.7138e-04
#
# Epoch 00036: saving model to data/checkpoint_model/cp-0036.ckpt
# Epoch 37/100
# 240/240 [==============================] - 299s 1s/step - loss: 3.7053e-04
#
# Epoch 00037: saving model to data/checkpoint_model/cp-0037.ckpt
# Epoch 38/100
# 240/240 [==============================] - 299s 1s/step - loss: 3.6797e-04
#
# Epoch 00038: saving model to data/checkpoint_model/cp-0038.ckpt
# Epoch 39/100
# 240/240 [==============================] - 301s 1s/step - loss: 3.6785e-04
#
# Epoch 00039: saving model to data/checkpoint_model/cp-0039.ckpt
# Epoch 40/100
# 240/240 [==============================] - 300s 1s/step - loss: 3.6439e-04
#
# Epoch 00040: saving model to data/checkpoint_model/cp-0040.ckpt
# Epoch 41/100
# 240/240 [==============================] - 300s 1s/step - loss: 3.6214e-04
#
# Epoch 00041: saving model to data/checkpoint_model/cp-0041.ckpt
# Epoch 42/100
# 240/240 [==============================] - 300s 1s/step - loss: 3.6145e-04
#
# Epoch 00042: saving model to data/checkpoint_model/cp-0042.ckpt
# Epoch 43/100
# 240/240 [==============================] - 300s 1s/step - loss: 3.6153e-04
#
# Epoch 00043: saving model to data/checkpoint_model/cp-0043.ckpt
# Epoch 44/100
# 240/240 [==============================] - 301s 1s/step - loss: 3.6151e-04
#
# Epoch 00044: saving model to data/checkpoint_model/cp-0044.ckpt
# Epoch 45/100
# 240/240 [==============================] - 300s 1s/step - loss: 3.6217e-04
#
# Epoch 00045: saving model to data/checkpoint_model/cp-0045.ckpt
# Epoch 46/100
# 240/240 [==============================] - 300s 1s/step - loss: 3.6068e-04
#
# Epoch 00046: saving model to data/checkpoint_model/cp-0046.ckpt
# Epoch 47/100
# 240/240 [==============================] - 301s 1s/step - loss: 3.6073e-04
#
# Epoch 00047: saving model to data/checkpoint_model/cp-0047.ckpt
# Epoch 48/100
# 240/240 [==============================] - 301s 1s/step - loss: 3.5989e-04
#
# Epoch 00048: saving model to data/checkpoint_model/cp-0048.ckpt
# Epoch 49/100
# 240/240 [==============================] - 299s 1s/step - loss: 3.5981e-04
#
# Epoch 00049: saving model to data/checkpoint_model/cp-0049.ckpt
# Epoch 50/100
# 240/240 [==============================] - 299s 1s/step - loss: 3.5996e-04
#
# Epoch 00050: saving model to data/checkpoint_model/cp-0050.ckpt
# Epoch 51/100
# 240/240 [==============================] - 299s 1s/step - loss: 3.6021e-04
#
# Epoch 00051: saving model to data/checkpoint_model/cp-0051.ckpt
# Epoch 52/100
# 240/240 [==============================] - 299s 1s/step - loss: 3.5893e-04
#
# Epoch 00052: saving model to data/checkpoint_model/cp-0052.ckpt
# Epoch 53/100
# 240/240 [==============================] - 300s 1s/step - loss: 3.5863e-04
#
# Epoch 00053: saving model to data/checkpoint_model/cp-0053.ckpt
# Epoch 54/100
# 240/240 [==============================] - 298s 1s/step - loss: 3.5919e-04
#
# Epoch 00054: saving model to data/checkpoint_model/cp-0054.ckpt
# Epoch 55/100
# 240/240 [==============================] - 298s 1s/step - loss: 3.5874e-04
#
# Epoch 00055: saving model to data/checkpoint_model/cp-0055.ckpt
# Epoch 56/100
# 240/240 [==============================] - 299s 1s/step - loss: 3.5931e-04
#
# Epoch 00056: saving model to data/checkpoint_model/cp-0056.ckpt
# Epoch 57/100
# 240/240 [==============================] - 300s 1s/step - loss: 3.5861e-04
#
# Epoch 00057: saving model to data/checkpoint_model/cp-0057.ckpt
# Epoch 58/100
# 240/240 [==============================] - 299s 1s/step - loss: 3.5812e-04
#
# Epoch 00058: saving model to data/checkpoint_model/cp-0058.ckpt
# Epoch 59/100
# 240/240 [==============================] - 300s 1s/step - loss: 3.5849e-04
#
# Epoch 00059: saving model to data/checkpoint_model/cp-0059.ckpt
# Epoch 60/100
# 240/240 [==============================] - 300s 1s/step - loss: 3.5766e-04
#
# Epoch 00060: saving model to data/checkpoint_model/cp-0060.ckpt
# Epoch 61/100
# 240/240 [==============================] - 299s 1s/step - loss: 3.5861e-04
#
# Epoch 00061: saving model to data/checkpoint_model/cp-0061.ckpt
# Epoch 62/100
# 240/240 [==============================] - 300s 1s/step - loss: 3.5786e-04
#
# Epoch 00062: saving model to data/checkpoint_model/cp-0062.ckpt
# Epoch 63/100
# 240/240 [==============================] - 299s 1s/step - loss: 3.5738e-04
#
# Epoch 00063: saving model to data/checkpoint_model/cp-0063.ckpt
# Epoch 64/100
# 240/240 [==============================] - 299s 1s/step - loss: 3.5754e-04
#
# Epoch 00064: saving model to data/checkpoint_model/cp-0064.ckpt
# Epoch 65/100
# 240/240 [==============================] - 300s 1s/step - loss: 3.5730e-04
#
# Epoch 00065: saving model to data/checkpoint_model/cp-0065.ckpt
# Epoch 66/100
# 240/240 [==============================] - 300s 1s/step - loss: 3.5773e-04
#
# Epoch 00066: saving model to data/checkpoint_model/cp-0066.ckpt
# Epoch 67/100
# 240/240 [==============================] - 300s 1s/step - loss: 3.5605e-04
#
# Epoch 00067: saving model to data/checkpoint_model/cp-0067.ckpt
# Epoch 68/100
# 240/240 [==============================] - 299s 1s/step - loss: 3.5667e-04
#
# Epoch 00068: saving model to data/checkpoint_model/cp-0068.ckpt
# Epoch 69/100
# 240/240 [==============================] - 299s 1s/step - loss: 3.5680e-04
#
# Epoch 00069: saving model to data/checkpoint_model/cp-0069.ckpt
# Epoch 70/100
# 240/240 [==============================] - 299s 1s/step - loss: 3.5601e-04
#
# Epoch 00070: saving model to data/checkpoint_model/cp-0070.ckpt
# Epoch 71/100
# 240/240 [==============================] - 299s 1s/step - loss: 3.5596e-04
#
# Epoch 00071: saving model to data/checkpoint_model/cp-0071.ckpt
# Epoch 72/100
# 240/240 [==============================] - 299s 1s/step - loss: 3.5572e-04
#
# Epoch 00072: saving model to data/checkpoint_model/cp-0072.ckpt
# Epoch 73/100
# 240/240 [==============================] - 298s 1s/step - loss: 3.5532e-04
#
# Epoch 00073: saving model to data/checkpoint_model/cp-0073.ckpt
# Epoch 74/100
# 240/240 [==============================] - 298s 1s/step - loss: 3.5485e-04
#
# Epoch 00074: saving model to data/checkpoint_model/cp-0074.ckpt
# Epoch 75/100
# 240/240 [==============================] - 299s 1s/step - loss: 3.5495e-04
#
# Epoch 00075: saving model to data/checkpoint_model/cp-0075.ckpt
# Epoch 76/100
# 240/240 [==============================] - 299s 1s/step - loss: 3.5522e-04
#
# Epoch 00076: saving model to data/checkpoint_model/cp-0076.ckpt
# Epoch 77/100
# 240/240 [==============================] - 303s 1s/step - loss: 3.5519e-04
#
# Epoch 00077: saving model to data/checkpoint_model/cp-0077.ckpt
# Epoch 78/100
# 240/240 [==============================] - 301s 1s/step - loss: 3.5478e-04
#
# Epoch 00078: saving model to data/checkpoint_model/cp-0078.ckpt
# Epoch 79/100
# 240/240 [==============================] - 299s 1s/step - loss: 3.5505e-04
#
# Epoch 00079: saving model to data/checkpoint_model/cp-0079.ckpt
# Epoch 80/100
# 240/240 [==============================] - 300s 1s/step - loss: 3.5432e-04
#
# Epoch 00080: saving model to data/checkpoint_model/cp-0080.ckpt
# Epoch 81/100
# 240/240 [==============================] - 300s 1s/step - loss: 3.5370e-04
#
# Epoch 00081: saving model to data/checkpoint_model/cp-0081.ckpt
# Epoch 82/100
# 240/240 [==============================] - 300s 1s/step - loss: 3.5428e-04
#
# Epoch 00082: saving model to data/checkpoint_model/cp-0082.ckpt
# Epoch 83/100
# 240/240 [==============================] - 301s 1s/step - loss: 3.5419e-04
#
# Epoch 00083: saving model to data/checkpoint_model/cp-0083.ckpt
# Epoch 84/100
# 240/240 [==============================] - 300s 1s/step - loss: 3.5337e-04
#
# Epoch 00084: saving model to data/checkpoint_model/cp-0084.ckpt
# Epoch 85/100
# 240/240 [==============================] - 299s 1s/step - loss: 3.5329e-04
#
# Epoch 00085: saving model to data/checkpoint_model/cp-0085.ckpt
# Epoch 86/100
# 240/240 [==============================] - 298s 1s/step - loss: 3.5280e-04
#
# Epoch 00086: saving model to data/checkpoint_model/cp-0086.ckpt
# Epoch 87/100
# 240/240 [==============================] - 299s 1s/step - loss: 3.5300e-04
#
# Epoch 00087: saving model to data/checkpoint_model/cp-0087.ckpt
# Epoch 88/100
# 240/240 [==============================] - 299s 1s/step - loss: 3.5300e-04
#
# Epoch 00088: saving model to data/checkpoint_model/cp-0088.ckpt
# Epoch 89/100
# 240/240 [==============================] - 299s 1s/step - loss: 3.5242e-04
#
# Epoch 00089: saving model to data/checkpoint_model/cp-0089.ckpt
# Epoch 90/100
# 240/240 [==============================] - 298s 1s/step - loss: 3.5235e-04
#
# Epoch 00090: saving model to data/checkpoint_model/cp-0090.ckpt
# Epoch 91/100
# 240/240 [==============================] - 297s 1s/step - loss: 3.5206e-04
#
# Epoch 00091: saving model to data/checkpoint_model/cp-0091.ckpt
# Epoch 92/100
# 240/240 [==============================] - 298s 1s/step - loss: 3.5207e-04
#
# Epoch 00092: saving model to data/checkpoint_model/cp-0092.ckpt
# Epoch 93/100
# 240/240 [==============================] - 298s 1s/step - loss: 3.5115e-04
#
# Epoch 00093: saving model to data/checkpoint_model/cp-0093.ckpt
# Epoch 94/100
# 240/240 [==============================] - 300s 1s/step - loss: 3.5185e-04
#
# Epoch 00094: saving model to data/checkpoint_model/cp-0094.ckpt
# Epoch 95/100
# 240/240 [==============================] - 300s 1s/step - loss: 3.5133e-04
#
# Epoch 00095: saving model to data/checkpoint_model/cp-0095.ckpt
# Epoch 96/100
# 240/240 [==============================] - 298s 1s/step - loss: 3.5138e-04
#
# Epoch 00096: saving model to data/checkpoint_model/cp-0096.ckpt
# Epoch 97/100
# 240/240 [==============================] - 299s 1s/step - loss: 3.5020e-04
#
# Epoch 00097: saving model to data/checkpoint_model/cp-0097.ckpt
# Epoch 98/100
# 240/240 [==============================] - 300s 1s/step - loss: 3.5128e-04
#
# Epoch 00098: saving model to data/checkpoint_model/cp-0098.ckpt
# Epoch 99/100
# 240/240 [==============================] - 299s 1s/step - loss: 3.5047e-04
#
# Epoch 00099: saving model to data/checkpoint_model/cp-0099.ckpt
# Epoch 100/100
# 240/240 [==============================] - 299s 1s/step - loss: 3.5081e-04
#
# Epoch 00100: saving model to data/checkpoint_model/cp-0100.ckpt

# %%
# plt.ylim([0.00005, 0.002])
plt.plot(range(100), hist.history['loss'])
# plt.plot(range(50), )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b4ea9a36807d> in <module>
#       1 # plt.ylim([0.00005, 0.002])
# ----> 2 plt.plot(range(100), hist.history['loss'])
#       3 # plt.plot(range(50), )
#
# NameError: name 'plt' is not defined

# %%
plt.savefig('history')
